# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plib
plib.rcParams.update(plib.rcParamsDefault)

# %%
column_names = [
    "class","cap_shape","cap_surface","cap_color","bruises","odor",
    "gill_attachment","gill_spacing","gill_size","gill_color","stalk_shape",
    "stalk_root","stalk_surface_above_ring","stalk_surface_below_ring",
    "stalk_color_above_ring","stalk_color_below_ring","veil_type","veil_color",
    "ring_number","ring_type","spore_print_color","population","habitat"
]

# %%
df = pd.read_csv("agaricus-lepiota.data", header=None, names=column_names)

# %%
df.head()
# Out:
#   class cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# ...

# %%
value_mappings = {
    'class': {'e': 'edible', 'p': 'poisonous'},
    'cap_shape': {'b': 'bell','c': 'conical','x': 'convex','f': 'flat','k': 'knobbed','s': 'sunken'},
    'cap_surface': {'f': 'fibrous','g': 'grooves','y': 'scaly','s': 'smooth'},
    'cap_color': {'n': 'brown','b': 'buff','c': 'cinnamon','g': 'gray','r': 'green','p': 'pink','u': 'purple','e': 'red','w': 'white','y': 'yellow'},
    'bruises': {'t': 'bruises','f': 'no'},
    'odor': {'a': 'almond','l': 'anise','c': 'creosote','y': 'fishy','f': 'foul','m': 'musty','n': 'none','p': 'pungent','s': 'spicy'},
    'gill_attachment': {'a': 'attached','d': 'descending','f': 'free','n': 'notched'},
    'gill_spacing': {'c': 'close','w': 'crowded','d': 'distant'},
    'gill_size': {'b': 'broad','n': 'narrow'},
    'gill_color': {'k': 'black','n': 'brown','b': 'buff','h': 'chocolate','g': 'gray','r': 'green','o': 'orange','p': 'pink','u': 'purple','e': 'red','w': 'white','y': 'yellow'},
    'stalk_shape': {'e': 'enlarging','t': 'tapering'},
    'stalk_root': {'b': 'bulbous','c': 'club','u': 'cup','e': 'equal','z': 'rhizomorphs','?': 'missing'},
    'stalk_surface_above_ring': {'f': 'fibrous','y': 'scaly','k': 'silky','s': 'smooth'},
    'stalk_surface_below_ring': {'f': 'fibrous','y': 'scaly','k': 'silky','s': 'smooth'},
    'stalk_color_above_ring': {'n': 'brown','b': 'buff','c': 'cinnamon','g': 'gray','o': 'orange','p': 'pink','e': 'red','w': 'white','y': 'yellow'},
    'stalk_color_below_ring': {'n': 'brown','b': 'buff','c': 'cinnamon','g': 'gray','o': 'orange','p': 'pink','e': 'red','w': 'white','y': 'yellow'},
    'veil_type': {'p': 'partial'},
    'veil_color': {'n': 'brown','o': 'orange','w': 'white','y': 'yellow'},
    'ring_number': {'n': 'none','o': 'one','t': 'two'},
    'ring_type': {'c': 'cobwebby','e': 'evanescent','f': 'flaring','l': 'large','n': 'none','p': 'pendant','s': 'sheathing','z': 'zone'},
    'spore_print_color': {'k': 'black','n': 'brown','b': 'buff','h': 'chocolate','r': 'green','o': 'orange','u': 'purple','w': 'white','y': 'yellow'},
    'population': {'a': 'abundant','c': 'clustered','n': 'numerous','s': 'scattered','v': 'several','y': 'solitary'},
    'habitat': {'g': 'grasses','l': 'leaves','m': 'meadows','p': 'paths','u': 'urban','w': 'waste','d': 'woods'}
}

# %%
for column, mapping in value_mappings.items():
    df[column] = df[column].map(mapping)

# %%
df.head()
# Out:
#        class cap_shape cap_surface cap_color  bruises     odor  \
# 0  poisonous    convex      smooth     brown  bruises  pungent
# 1     edible    convex      smooth    yellow  bruises   almond
# 2     edible      bell      smooth     white  bruises    anise
# 3  poisonous    convex       scaly     white  bruises  pungent
# 4     edible    convex      smooth      gray       no     none
#
#   gill_attachment gill_spacing gill_size gill_color  ...  \
# 0            free        close    narrow      black  ...
# 1            free        close     broad      black  ...
# 2            free        close     broad      brown  ...
# 3            free        close    narrow      brown  ...
# 4            free      crowded     broad      black  ...
#
#   stalk_surface_below_ring stalk_color_above_ring stalk_color_below_ring  \
# 0                   smooth                  white                  white
# 1                   smooth                  white                  white
# ...

# %%
df.tail()
# Out:
#           class cap_shape cap_surface cap_color bruises   odor  \
# 8119     edible   knobbed      smooth     brown      no   none
# 8120     edible    convex      smooth     brown      no   none
# 8121     edible      flat      smooth     brown      no   none
# 8122  poisonous   knobbed       scaly     brown      no  fishy
# 8123     edible    convex      smooth     brown      no   none
#
#      gill_attachment gill_spacing gill_size gill_color  ...  \
# 8119        attached        close     broad     yellow  ...
# 8120        attached        close     broad     yellow  ...
# 8121        attached        close     broad      brown  ...
# 8122            free        close    narrow       buff  ...
# 8123        attached        close     broad     yellow  ...
#
#      stalk_surface_below_ring stalk_color_above_ring stalk_color_below_ring  \
# 8119                   smooth                 orange                 orange
# ...

# %%
df.describe()
# Out:
#          class cap_shape cap_surface cap_color bruises  odor gill_attachment  \
# count     8124      8124        8124      8124    8124  8124            8124
# unique       2         6           4        10       2     9               2
# top     edible    convex       scaly     brown      no  none            free
# freq      4208      3656        3244      2284    4748  3528            7914
#
#        gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top           close     broad       buff  ...                   smooth
# freq           6812      5612       1728  ...                     4936
#
#        stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# count                    8124                   8124      8124       8124
# ...

# %%
(df['class'] == 'poisonous').describe()
# Out:
# count      8124
# unique        2
# top       False
# freq       4208
# Name: class, dtype: object

# %%
df.count()
# Out:
# class                       8124
# cap_shape                   8124
# cap_surface                 8124
# cap_color                   8124
# bruises                     8124
# odor                        8124
# gill_attachment             8124
# gill_spacing                8124
# gill_size                   8124
# gill_color                  8124
# stalk_shape                 8124
# stalk_root                  7932
# stalk_surface_above_ring    8124
# stalk_surface_below_ring    8124
# stalk_color_above_ring      8124
# stalk_color_below_ring      8124
# veil_type                   8124
# veil_color                  8124
# ring_number                 8124
# ring_type                   8124
# spore_print_color           8124
# population                  8124
# habitat                     8124
# dtype: int64

# %%
(df['class'] == 'poisonous').count()
# Out:
# 8124

# %%
sns.countplot(data=df, x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
plib.show()

# %%
sns.countplot(data=df, x='class', hue='cap_color')
plib.show()

# %%
sns.countplot(data=df, x='class', hue='gill_color')
plib.show()

# %%
sns.countplot(data=df, x='class', hue='stalk_color_above_ring')
plib.show()

# %%
sns.countplot(data=df, x='class', hue='stalk_color_below_ring')
plib.show()

# %%
sns.countplot(data=df, x='class', hue='spore_print_color')
plib.show()

# %%
color_fields = ["stalk_color_below_ring", "stalk_color_above_ring", "gill_color", "cap_color", "spore_print_color"] #all five fields
melted_df = df.melt(id_vars="class", value_vars=color_fields, value_name="total color") # melt considers all fields as one

# %%
sns.countplot(data=melted_df, x="class", hue="total color")
plib.show()

# %%
df['poisonous_binary'] = df['class'].map({'poisonous': 1, 'edible': 0}) #map poisonous/edible to 1 and 0 for calculations (.mean won't work on strings)
cap_color_rates = df.groupby("cap_color")['poisonous_binary'].mean().sort_values(ascending=False)

# %%
sns.barplot(x=cap_color_rates.index, y=cap_color_rates.values, palette="coolwarm_r")  #index = labels, values = rates of the data
plib.xlabel("Cap Color")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
gill_color_rates = df.groupby("gill_color")['poisonous_binary'].mean().sort_values(ascending=False)

# %%
sns.barplot(x=gill_color_rates.index, y=gill_color_rates.values, palette="coolwarm_r")
plib.xlabel("Gill Color")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
stalk_color_above_ring_rates = df.groupby("stalk_color_above_ring")['poisonous_binary'].mean().sort_values(ascending=False)

# %%
sns.barplot(x=stalk_color_above_ring_rates.index, y=stalk_color_above_ring_rates.values, palette="coolwarm_r")
plib.xlabel("Stalk Color Above Ring")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
stalk_color_below_ring_rates = df.groupby("stalk_color_below_ring")['poisonous_binary'].mean().sort_values(ascending=False)

# %%
sns.barplot(x=stalk_color_below_ring_rates.index, y=stalk_color_below_ring_rates.values, palette="coolwarm_r")
plib.xlabel("Stalk Color Below Ring")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
spore_print_color_rates = df.groupby("spore_print_color")['poisonous_binary'].mean().sort_values(ascending=False)

# %%
sns.barplot(x=spore_print_color_rates.index, y=spore_print_color_rates.values, palette="coolwarm_r")
plib.xlabel("Spore Print Color")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
color_fields = ["stalk_color_below_ring", "stalk_color_above_ring", "gill_color", "cap_color", "spore_print_color"]
melted_df = df.melt(id_vars="poisonous_binary", value_vars=color_fields, var_name="feature", value_name="color")
color_rates = melted_df.groupby("color")["poisonous_binary"].mean().sort_values(ascending=False)

# %%
sns.barplot(x=color_rates.index, y=color_rates.values, palette="coolwarm_r")
plib.xlabel("Color Across Five Fields")
plib.ylabel("Poisonous Rate")
plib.xticks(rotation=45)
plib.show()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.describe(include='all')
# Out:
#          class cap_shape cap_surface cap_color bruises  odor gill_attachment  \
# count     8124      8124        8124      8124    8124  8124            8124
# unique       2         6           4        10       2     9               2
# top     edible    convex       scaly     brown      no  none            free
# freq      4208      3656        3244      2284    4748  3528            7914
# mean       NaN       NaN         NaN       NaN     NaN   NaN             NaN
# std        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# min        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 25%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 50%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 75%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# max        NaN       NaN         NaN       NaN     NaN   NaN             NaN
#
# ...

# %%
cap_freq = df['cap_color'].value_counts()
print(cap_freq)
# Out:
# cap_color
# brown       2284
# gray        1840
# red         1500
# yellow      1072
# white       1040
# buff         168
# pink         144
# cinnamon      44
# purple        16
# green         16
# Name: count, dtype: int64

# %%
gill_freq = df['gill_color'].value_counts()
print(gill_freq)
# Out:
# gill_color
# buff         1728
# pink         1492
# white        1202
# brown        1048
# gray          752
# chocolate     732
# purple        492
# black         408
# red            96
# yellow         86
# orange         64
# green          24
# Name: count, dtype: int64

# %%
above_freq = df['stalk_color_above_ring'].value_counts()
print(above_freq)
# Out:
# stalk_color_above_ring
# white       4464
# pink        1872
# gray         576
# brown        448
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow         8
# Name: count, dtype: int64

# %%
below_freq = df['stalk_color_below_ring'].value_counts()
print(below_freq)
# Out:
# stalk_color_below_ring
# white       4384
# pink        1872
# gray         576
# brown        512
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow        24
# Name: count, dtype: int64
